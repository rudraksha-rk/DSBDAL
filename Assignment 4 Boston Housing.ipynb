# %% [markdown]
# **Data Analytics**

# %% [markdown]
# Perform the following operations on any open source dataset. Create a Linear Regression Model using Python to predict home prices using Boston Housing Dataset (from kaggle). The boston housing dataset contains information about various houses in Boston through different parameters. There are 506 samples and 14 feature variables in this dataset. The objective is to predict the values of prices of house using given features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c59a24dc-8824-4489-b3f7-5ea653572bbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c59a24dc-8824-4489-b3f7-5ea653572bbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("housing.csv")

# %%
df
# Out:
#       ID     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# ...

# %%
df.head()
# Out:
#    ID     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   CRIM     333 non-null    float64
#  2   ZN       333 non-null    float64
#  3   INDUS    333 non-null    float64
#  4   CHAS     333 non-null    int64
#  5   NOX      333 non-null    float64
#  6   RM       333 non-null    float64
#  7   AGE      333 non-null    float64
#  8   DIS      333 non-null    float64
#  9   RAD      333 non-null    int64
#  10  TAX      333 non-null    int64
#  11  PTRATIO  333 non-null    float64
#  12  B        333 non-null    float64
#  13  LSTAT    333 non-null    float64
#  14  MEDV     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
df.describe(include="all")
# Out:
#                ID        CRIM          ZN       INDUS        CHAS         NOX  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %%
df.isnull().sum()
# Out:
# ID         0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df['CRIM']=df['CRIM'].fillna(df['CRIM'].mean())
df['ZN']=df['ZN'].fillna(df['ZN'].mean())
df['INDUS']=df['INDUS'].fillna(df['INDUS'].mean())
df['CHAS']=df['CHAS'].fillna(df['CHAS'].mean())
df['AGE']=df['AGE'].fillna(df['AGE'].mean())
df['LSTAT']=df['LSTAT'].fillna(df['LSTAT'].mean())

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df
# Out:
#       ID     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# ...

# %%
x=df.drop(['MEDV'],axis=1)
y=df['MEDV']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (266, 14)
# (67, 14)
# (266,)
# (67,)

# %%
import sklearn
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
model=lm.fit(xtrain,ytrain)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Model evaluation for training set

# %%
ytrain_pred=lm.predict(xtrain)
mse=mean_squared_error(ytrain,ytrain_pred)
rmse=np.sqrt(mse)
r2=r2_score(ytrain,ytrain_pred)
print("The model performance for training set")
print("--------------------------------------")
print("MSE is {}".format(mse))
print("RMSE is {}".format(rmse))
print("R2 score is {}".format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# MSE is 22.10292476008162
# RMSE is 4.7013747734127325
# R2 score is 0.7330398034933922

# %% [markdown]
# Model evaluation for testing set

# %%
ytest_pred=lm.predict(xtest)
mse=mean_squared_error(ytest,ytest_pred)
rmse=np.sqrt(mse)
r2=r2_score(ytest,ytest_pred)
print("The model performance for testing set")
print("-------------------------------------")
print("MSE is {}".format(mse))
print("RMSE is {}".format(rmse))
print("R2 score is {}".format(r2))
# Out:
# The model performance for testing set
# -------------------------------------
# MSE is 23.821583889010856
# RMSE is 4.880735998700489
# R2 score is 0.7290582208058237
